# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import os
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

# %% [markdown]
# ### convert XML format data to YOLO Format Data

# %%
import os
import xml.etree.ElementTree as ET

# Input and output directories
input_dir = 'path/to/xml_files_folder'  #input directory of XML files
output_dir = 'path/to/store_output_folder'  #ouput dirctory of newly created yolo text files

# Function to convert bounding box coordinates from Xml files  to YOLO format

def convert_coordinates(size, box):
    dw = 1.0 / size[0]
    dh = 1.0 / size[1]
    x = (box[0] + box[2]) / 2.0
    y = (box[1] + box[3]) / 2.0
    w = box[2] - box[0]
    h = box[3] - box[1]
    x = x * dw
    w = w * dw
    y = y * dh
    h = h * dh
    return x, y, w, h

# Function to convert class name to YOLO class index
def convert_class_name_to_index(class_name):
    if class_name == 'without_mask':
        return 0
    elif class_name == 'with_mask':
        return 1
    else:
        return None


# Create the output directory if it doesn't exist
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Iterate through each XML file in the input directory
for filename in os.listdir(input_dir):
    if filename.endswith('.xml'):
        # Parse XML file
        tree = ET.parse(os.path.join(input_dir, filename))
        root = tree.getroot()

        # Get image size
        size = (int(root.find('size').find('width').text), int(root.find('size').find('height').text))

        # Create YOLO format text file
        output_filename = os.path.splitext(filename)[0] + '.txt'
        with open(os.path.join(output_dir, output_filename), 'w') as f:
            # Iterate through each object
            for obj in root.findall('object'):
                class_name = obj.find('name').text
                class_index = convert_class_name_to_index(class_name)
                if class_index is not None:
                    bbox = obj.find('bndbox')
                    xmin = int(bbox.find('xmin').text)
                    ymin = int(bbox.find('ymin').text)
                    xmax = int(bbox.find('xmax').text)
                    ymax = int(bbox.find('ymax').text)
                    # Convert bounding box coordinates to YOLO format
                    x, y, w, h = convert_coordinates(size, (xmin, ymin, xmax, ymax))
                    # Write to YOLO format text file
                    f.write(f"{class_index} {x} {y} {w} {h}\n")

# %% [markdown]
# ## Confirm YOLO annotations

# %% [markdown]
# verify the XML to YOLO TXT conversion by randomly visualizing the images with generated yolo text files from the previous code

# %%
import os
import random
import shutil

# Directory paths
images_dir = "raw data/images"
annotations_dir = "raw data/labels"

# Function to convert YOLO format bounding box to integers
def convert_yolo_to_int(box, image_width, image_height):
    x_center, y_center, w, h = box
    x_center *= image_width
    y_center *= image_height
    w *= image_width
    h *= image_height
    x_min = int(x_center - (w / 2))
    y_min = int(y_center - (h / 2))
    x_max = int(x_center + (w / 2))
    y_max = int(y_center + (h / 2))
    return x_min, y_min, x_max, y_max

# Define function to display images with annotations in a grid
def display_images_with_annotations_grid(images_dir, annotations_dir, num_images=25, grid_shape=(5, 5)):
    # Get list of image files
    image_files = os.listdir(images_dir)
    # Randomly select num_images images
    selected_images = random.sample(image_files, min(num_images, len(image_files)))
    # Create subplots
    fig, axes = plt.subplots(*grid_shape, figsize=(15, 15))
    # Flatten axes if grid_shape is not provided correctly
    if not isinstance(axes, (list, np.ndarray)):
        axes = [axes]
    else:
        axes = axes.flatten()
    # Iterate through selected images
    for i, image_file in enumerate(selected_images):
        try:
            # Get corresponding annotation file
            annotation_file = os.path.join(annotations_dir, os.path.splitext(image_file)[0] + '.txt')
            # Read image
            image_path = os.path.join(images_dir, image_file)
            image = Image.open(image_path)
            image_width, image_height = image.size
            # Display the image
            axes[i].imshow(image)
            axes[i].axis('off')  # Disable axis
            axes[i].set_title(image_file)  # Set title as image filename
            # Check if annotation file exists
            if os.path.exists(annotation_file):
                # Read YOLO format text file
                with open(annotation_file, 'r') as f:
                    lines = f.readlines()
                # Iterate through each line in the YOLO format text file
                for line in lines:
                    class_index, x_center, y_center, w, h = map(float, line.split())
                    # Convert YOLO format bounding box to integers
                    x_min, y_min, x_max, y_max = convert_yolo_to_int((x_center, y_center, w, h), image_width, image_height)
                    # Calculate width and height of the bounding box
                    bbox_width = x_max - x_min
                    bbox_height = y_max - y_min
                    # Create a Rectangle patch
                    rect = patches.Rectangle((x_min, y_min), bbox_width, bbox_height, linewidth=1, edgecolor='r', facecolor='none')
                    # Add the patch to the Axes
                    axes[i].add_patch(rect)
                    # Add label name to the bounding box
                    class_name = 'Class ' + str(int(class_index))
                    axes[i].text(x_min, y_min - 5, class_name, color='r', fontsize=8)
        except Exception as e:
            print(f"Error processing file: {image_file}. Error message: {str(e)}")

    # Hide any empty subplots
    for j in range(len(selected_images), len(axes)):
        axes[j].axis('off')
    plt.tight_layout()  # Adjust layout
    plt.show()

# Display 25 images with annotations in a grid
display_images_with_annotations_grid(images_dir, annotations_dir, num_images=25, grid_shape=(5, 5))

# %% [markdown]
# The conversion was successful!

# %% [markdown]
# ### Check for Class Imbalance

# %%
import os

# Directory containing YOLO format text files
yolo_txt_dir = 'raw data/labels'

def count_class_frequency(yolo_txt_dir):
    class_frequency = {}
    # Iterate through each YOLO format text file in the directory
    for filename in os.listdir(yolo_txt_dir):
        if filename.endswith('.txt'):
            # Read the content of the text file
            with open(os.path.join(yolo_txt_dir, filename), 'r') as file:
                lines = file.readlines()
            # Iterate through each line in the text file
            for line in lines:
                class_index = int(line.split()[0])
                # Update the class frequency dictionary
                if class_index not in class_frequency:
                    class_frequency[class_index] = 1
                else:
                    class_frequency[class_index] += 1
    return class_frequency



# Count class frequency
class_frequency = count_class_frequency(yolo_txt_dir)

# Print class frequency
for class_index, frequency in class_frequency.items():
    print(f"Class {class_index}: {frequency} occurrences")
# Out:
# Class 0: 3100 occurrences
# Class 1: 3232 occurrences

# %% [markdown]
# Hence the classes are approximately Balanced

# %% [markdown]
# ### divide data into train val and test folders for YOLOv8

# %%
# do not run this code again, its already been executed and the results are stored in the provided paths

import os
import shutil
import random


# Define paths
master_image_folder = "raw data/images"  # folder containing all images
master_label_folder = "raw data/labels"  # folder containing all labels

train_folder = "data/Data/train"
test_folder = "data/Data/test"
validation_folder = "data/Data/valid"



def create_folders_if_not_exist(folder_paths):
    for folder_path in folder_paths:
        os.makedirs(folder_path, exist_ok=True)

def copy_images_and_labels(images_folder, labels_folder, image_list, destination_folder):
    for image_file in image_list:
        image_path = os.path.join(images_folder, image_file)
        label_file = os.path.splitext(image_file)[0] + '.txt'
        label_path = os.path.join(labels_folder, label_file)
        if os.path.exists(image_path):
            shutil.copy(image_path, os.path.join(destination_folder, 'images', image_file))
        if os.path.exists(label_path):
            shutil.copy(label_path, os.path.join(destination_folder, 'labels', label_file))

def split_dataset(master_image_folder, master_label_folder, train_folder, test_folder, validation_folder, split_ratio=(0.8, 0.1, 0.1)):
    # Create train, test, and validation folders if they don't exist
    create_folders_if_not_exist([train_folder, test_folder, validation_folder])

    # Create images and labels folders inside train, test, and validation folders
    create_folders_if_not_exist([os.path.join(train_folder, 'images'), os.path.join(train_folder, 'labels')])
    create_folders_if_not_exist([os.path.join(test_folder, 'images'), os.path.join(test_folder, 'labels')])
    create_folders_if_not_exist([os.path.join(validation_folder, 'images'), os.path.join(validation_folder, 'labels')])

    # Get list of image files in the master image folder
    image_files = os.listdir(master_image_folder)
    num_images = len(image_files)
    
    # Shuffle the list of image files
    random.shuffle(image_files)

    # Calculate number of images for train, test, and validation sets
    num_train = int(split_ratio[0] * num_images)
    num_test = int(split_ratio[1] * num_images)
    num_validation = num_images - num_train - num_test

    # Assign images to train, test, and validation sets
    train_images = image_files[:num_train]
    test_images = image_files[num_train:num_train+num_test]
    validation_images = image_files[num_train+num_test:]

    # Copy images and label files to corresponding folders
    copy_images_and_labels(master_image_folder, master_label_folder, train_images, train_folder)
    copy_images_and_labels(master_image_folder, master_label_folder, test_images, test_folder)
    copy_images_and_labels(master_image_folder, master_label_folder, validation_images, validation_folder)



# Split dataset
split_dataset(master_image_folder, master_label_folder, train_folder, test_folder, validation_folder)

# %% [markdown]
# ### Rename files
# ### before startiing with preprocessng the data, it is always better we rename all the files serially

# %%
import os

# Function to rename files in a directory
def rename_files(directory):
    # Get list of files in the directory
    files = os.listdir(directory)
    # Sort files to ensure consistent numbering
    files.sort()
    # Initialize counter
    counter = 1
    # Iterate through files
    for file_name in files:
        # Get file extension
        file_ext = os.path.splitext(file_name)[1]
        # Construct new file name with counter
        new_file_name = str(counter).zfill(4) + file_ext
        # Rename the file
        os.rename(os.path.join(directory, file_name), os.path.join(directory, new_file_name))
        # Increment counter
        counter += 1

# Directories
images_dir = "raw data/images"
labels_dir =  "raw data/labels"

## Rename files in images directory
# rename_files(images_dir)

## Rename files in labels directory
# rename_files(labels_dir)

# %% [markdown]
# ### find invalid text files in the labels folder

# %%
import os

# Function to check if a line adheres to the YOLO annotation format
def is_valid_yolo_format(line):
    # Split the line by space and check if there are exactly 5 elements
    elements = line.split()
    if len(elements) != 5:
        return False
    try:
        # Attempt to convert each element to float
        float_elements = [float(e) for e in elements]
        # Check if class_id is an integer
        if not float_elements[0].is_integer():
            return False
    except ValueError:
        return False
    return True

# Function to find files in the labels folder that do not adhere to YOLO annotation format
def find_invalid_files(folder_path):
    invalid_files = []
    # Iterate over each file in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".txt"):
            file_path = os.path.join(folder_path, filename)
            with open(file_path, "r") as file:
                # Read each line and check if it adheres to YOLO annotation format
                for line_num, line in enumerate(file, start=1):
                    if not is_valid_yolo_format(line.strip()):
                        invalid_files.append(filename)
                        break  # No need to continue checking once an invalid line is found
    return invalid_files

# Replace 'labels' with the path to your labels folder
folder_path = "C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels"
invalid_files = find_invalid_files(folder_path)

# Print the list of invalid files and the count
print("Number of files with invalid YOLO annotation format:", len(invalid_files))
print("Files with invalid YOLO annotation format:")
for filename in invalid_files:
    print(filename)
# Out:
# Number of files with invalid YOLO annotation format: 0
# Files with invalid YOLO annotation format:

# %% [markdown]
# ### Delete abnormal image-text pair files

# %%
import os

def delete_image_and_labels(image_dir, labels_dir, files_to_delete):
    deleted_count = 0
    # Delete image files
    for file in files_to_delete:
        image_path = os.path.join(image_dir, os.path.splitext(file)[0] + ".jpg")  # Assuming images have .jpg extension
        label_path = os.path.join(labels_dir, file)
        if os.path.exists(image_path):
            os.remove(image_path)
            deleted_count += 1
            print(f"Deleted {image_path}")
        if os.path.exists(label_path):
            os.remove(label_path)
            deleted_count += 1
            print(f"Deleted {label_path}")
    return deleted_count

# Example usage:
image_directory = "C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images"
labels_directory = "C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels"
files_to_delete = invalid_files  # List of text files to delete along with corresponding images

deleted_count = delete_image_and_labels(image_directory, labels_directory, files_to_delete)
print(f"Total files deleted: {deleted_count}")
# Out:
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0008.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0008.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0009.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0009.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0010.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0010.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0014.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0014.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0015.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0015.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0016.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0016.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0025.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0025.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0026.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0026.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0027.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0027.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0028.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0028.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0029.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0029.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0030.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0030.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0031.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0031.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0046.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0046.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0047.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0047.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0048.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0048.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0049.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0049.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0050.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0050.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0051.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0051.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0064.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0064.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0065.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0065.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0066.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0066.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0067.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0067.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0068.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0068.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0069.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0069.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0070.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0070.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0071.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0071.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0072.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0072.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0073.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0073.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0074.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0074.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0075.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0075.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0076.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0076.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0077.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0077.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0081.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0081.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0082.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0082.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0083.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0083.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0084.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0084.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\0085.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\0085.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\1737.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\1737.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\1738.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\1738.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2006.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2006.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2007.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2007.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2008.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2008.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2009.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2009.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2010.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2010.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2011.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2011.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2012.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2012.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2013.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2013.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2014.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2014.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2015.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2015.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2016.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2016.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2017.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2017.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2018.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2018.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2019.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2019.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2020.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2020.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2021.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2021.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2022.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2022.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2023.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2023.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2024.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2024.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2025.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2025.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2026.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2026.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2027.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2027.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2065.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2065.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2066.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2066.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2067.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2067.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2093.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2093.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2094.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2094.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2115.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2115.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2116.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2116.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2117.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2117.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2141.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2141.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2142.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2142.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2166.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2166.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2167.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2167.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2168.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2168.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2187.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2187.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2188.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2188.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2189.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2189.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2213.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2213.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2214.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2214.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2215.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2215.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2250.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2250.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2251.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2251.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2252.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2252.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2265.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2265.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2266.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2266.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2267.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2267.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2287.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2287.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2288.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2288.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2289.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2289.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2290.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2290.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2291.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2291.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2292.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2292.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2293.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2293.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2294.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2294.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2295.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2295.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2296.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2296.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2297.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2297.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2298.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2298.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2299.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2299.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2300.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2300.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2301.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2301.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2302.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2302.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2303.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2303.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2304.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2304.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2305.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2305.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2306.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2306.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2307.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2307.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2308.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2308.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2309.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2309.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2310.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2310.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2311.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2311.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2312.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2312.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2313.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2313.txt
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_images\2314.jpg
# Deleted C:/Users/arnav/Downloads/face detection.v9i.yolov8/new/selected_labels\2314.txt
# Total files deleted: 230

# %% [markdown]
# ### change class ids to any number
# the face detection data consisting of faces without mask  was use to balace the class "NO mask" in our current dataset of mask and no mask detection, the face detection data contains the front, side profiles of the face with different classes for both for example front face : 0, side face : 1, but faces without masks "NO mask" has the class id of 0, so we rename all the class ids of face detection data to 0

# %%
import os

def change_class_id_to_zero(labels_folder):
    # Iterate over each file in the labels folder
    for filename in os.listdir(labels_folder):
        if filename.endswith(".txt"):
            file_path = os.path.join(labels_folder, filename)
            # Read the contents of the file
            with open(file_path, "r") as file:
                lines = file.readlines()
            # Modify each line to change class_id to 0
            modified_lines = []
            for line in lines:
                elements = line.split()
                if len(elements) == 5:
                    # Change the class_id to 0------------------------
                    elements[0] = '0'
                    # Join the elements back into a line
                    modified_line = ' '.join(elements) + '\n'
                    modified_lines.append(modified_line)
            # Write the modified lines back to the file
            with open(file_path, "w") as file:
                file.writelines(modified_lines)
            print(f"Class IDs changed to 0 in file: {filename}")

# Example usage:
labels_folder = "path/to/labels_folder"
# change_class_id_to_zero(labels_folder)

# this code has already been executed and should not be rerun as a slightest mistake in the given path may cause dataset alteration
# Out:
# Class IDs changed to 0 in file: 0001.txt
# Class IDs changed to 0 in file: 0002.txt
# Class IDs changed to 0 in file: 0003.txt
# Class IDs changed to 0 in file: 0004.txt
# Class IDs changed to 0 in file: 0005.txt
# Class IDs changed to 0 in file: 0006.txt
# Class IDs changed to 0 in file: 0007.txt
# Class IDs changed to 0 in file: 0011.txt
# Class IDs changed to 0 in file: 0012.txt
# Class IDs changed to 0 in file: 0013.txt
# Class IDs changed to 0 in file: 0017.txt
# Class IDs changed to 0 in file: 0018.txt
# Class IDs changed to 0 in file: 0019.txt
# Class IDs changed to 0 in file: 0020.txt
# Class IDs changed to 0 in file: 0021.txt
# Class IDs changed to 0 in file: 0022.txt
# Class IDs changed to 0 in file: 0023.txt
# Class IDs changed to 0 in file: 0024.txt
# Class IDs changed to 0 in file: 0032.txt
# Class IDs changed to 0 in file: 0033.txt
# Class IDs changed to 0 in file: 0034.txt
# Class IDs changed to 0 in file: 0035.txt
# Class IDs changed to 0 in file: 0036.txt
# Class IDs changed to 0 in file: 0037.txt
# Class IDs changed to 0 in file: 0038.txt
# Class IDs changed to 0 in file: 0039.txt
# Class IDs changed to 0 in file: 0040.txt
# Class IDs changed to 0 in file: 0041.txt
# Class IDs changed to 0 in file: 0042.txt
# Class IDs changed to 0 in file: 0043.txt
# Class IDs changed to 0 in file: 0044.txt
# Class IDs changed to 0 in file: 0045.txt
# Class IDs changed to 0 in file: 0052.txt
# Class IDs changed to 0 in file: 0053.txt
# Class IDs changed to 0 in file: 0054.txt
# Class IDs changed to 0 in file: 0055.txt
# Class IDs changed to 0 in file: 0056.txt
# Class IDs changed to 0 in file: 0057.txt
# Class IDs changed to 0 in file: 0058.txt
# Class IDs changed to 0 in file: 0059.txt
# Class IDs changed to 0 in file: 0060.txt
# Class IDs changed to 0 in file: 0061.txt
# Class IDs changed to 0 in file: 0062.txt
# Class IDs changed to 0 in file: 0063.txt
# Class IDs changed to 0 in file: 1186.txt
# Class IDs changed to 0 in file: 1187.txt
# Class IDs changed to 0 in file: 1188.txt
# Class IDs changed to 0 in file: 1189.txt
# Class IDs changed to 0 in file: 1190.txt
# Class IDs changed to 0 in file: 1191.txt
# Class IDs changed to 0 in file: 1192.txt
# Class IDs changed to 0 in file: 1193.txt
# Class IDs changed to 0 in file: 1194.txt
# Class IDs changed to 0 in file: 1195.txt
# Class IDs changed to 0 in file: 1196.txt
# Class IDs changed to 0 in file: 1197.txt
# Class IDs changed to 0 in file: 1198.txt
# Class IDs changed to 0 in file: 1199.txt
# Class IDs changed to 0 in file: 1200.txt
# Class IDs changed to 0 in file: 1201.txt
# Class IDs changed to 0 in file: 1202.txt
# Class IDs changed to 0 in file: 1203.txt
# Class IDs changed to 0 in file: 1204.txt
# Class IDs changed to 0 in file: 1205.txt
# Class IDs changed to 0 in file: 1206.txt
# Class IDs changed to 0 in file: 1207.txt
# Class IDs changed to 0 in file: 1208.txt
# ...
# Class IDs changed to 0 in file: 2058.txt
# Class IDs changed to 0 in file: 2059.txt
# Class IDs changed to 0 in file: 2060.txt
# Class IDs changed to 0 in file: 2061.txt
# Class IDs changed to 0 in file: 2062.txt
# Class IDs changed to 0 in file: 2063.txt
# Class IDs changed to 0 in file: 2064.txt
# Class IDs changed to 0 in file: 2068.txt
# Class IDs changed to 0 in file: 2069.txt
# Class IDs changed to 0 in file: 2070.txt
# Class IDs changed to 0 in file: 2071.txt
# Class IDs changed to 0 in file: 2072.txt
# Class IDs changed to 0 in file: 2073.txt
# Class IDs changed to 0 in file: 2074.txt
# Class IDs changed to 0 in file: 2075.txt
# Class IDs changed to 0 in file: 2076.txt
# Class IDs changed to 0 in file: 2077.txt
# Class IDs changed to 0 in file: 2078.txt
# Class IDs changed to 0 in file: 2079.txt
# Class IDs changed to 0 in file: 2080.txt
# Class IDs changed to 0 in file: 2081.txt
# Class IDs changed to 0 in file: 2082.txt
# Class IDs changed to 0 in file: 2083.txt
# Class IDs changed to 0 in file: 2084.txt
# Class IDs changed to 0 in file: 2085.txt
# Class IDs changed to 0 in file: 2086.txt
# Class IDs changed to 0 in file: 2087.txt
# Class IDs changed to 0 in file: 2088.txt
# Class IDs changed to 0 in file: 2089.txt
# Class IDs changed to 0 in file: 2090.txt
# Class IDs changed to 0 in file: 2091.txt
# Class IDs changed to 0 in file: 2092.txt
# Class IDs changed to 0 in file: 2095.txt
# Class IDs changed to 0 in file: 2096.txt
# Class IDs changed to 0 in file: 2097.txt
# Class IDs changed to 0 in file: 2098.txt
# Class IDs changed to 0 in file: 2099.txt
# Class IDs changed to 0 in file: 2100.txt
# Class IDs changed to 0 in file: 2101.txt
# Class IDs changed to 0 in file: 2102.txt
# Class IDs changed to 0 in file: 2103.txt
# Class IDs changed to 0 in file: 2104.txt
# Class IDs changed to 0 in file: 2105.txt
# Class IDs changed to 0 in file: 2106.txt
# Class IDs changed to 0 in file: 2107.txt
# Class IDs changed to 0 in file: 2108.txt
# Class IDs changed to 0 in file: 2109.txt
# Class IDs changed to 0 in file: 2110.txt
# Class IDs changed to 0 in file: 2111.txt
# Class IDs changed to 0 in file: 2112.txt
# Class IDs changed to 0 in file: 2113.txt
# Class IDs changed to 0 in file: 2114.txt
# Class IDs changed to 0 in file: 2118.txt
# Class IDs changed to 0 in file: 2119.txt
# Class IDs changed to 0 in file: 2120.txt
# Class IDs changed to 0 in file: 2121.txt
# Class IDs changed to 0 in file: 2122.txt
# Class IDs changed to 0 in file: 2123.txt
# Class IDs changed to 0 in file: 2124.txt
# Class IDs changed to 0 in file: 2125.txt
# Class IDs changed to 0 in file: 2126.txt
# Class IDs changed to 0 in file: 2127.txt
# Class IDs changed to 0 in file: 2128.txt
# Class IDs changed to 0 in file: 2129.txt
# Class IDs changed to 0 in file: 2130.txt
# Class IDs changed to 0 in file: 2131.txt
# Class IDs changed to 0 in file: 2132.txt
# Class IDs changed to 0 in file: 2133.txt
# Class IDs changed to 0 in file: 2134.txt
# Class IDs changed to 0 in file: 2135.txt
# Class IDs changed to 0 in file: 2136.txt
# Class IDs changed to 0 in file: 2137.txt
# Class IDs changed to 0 in file: 2138.txt
# Class IDs changed to 0 in file: 2139.txt
# Class IDs changed to 0 in file: 2140.txt
# Class IDs changed to 0 in file: 2143.txt
# Class IDs changed to 0 in file: 2144.txt
# Class IDs changed to 0 in file: 2145.txt
# Class IDs changed to 0 in file: 2146.txt
# Class IDs changed to 0 in file: 2147.txt
# Class IDs changed to 0 in file: 2148.txt
# Class IDs changed to 0 in file: 2149.txt
# Class IDs changed to 0 in file: 2150.txt
# Class IDs changed to 0 in file: 2151.txt
# Class IDs changed to 0 in file: 2152.txt
# Class IDs changed to 0 in file: 2153.txt
# Class IDs changed to 0 in file: 2154.txt
# Class IDs changed to 0 in file: 2155.txt
# Class IDs changed to 0 in file: 2156.txt
# Class IDs changed to 0 in file: 2157.txt
# Class IDs changed to 0 in file: 2158.txt
# Class IDs changed to 0 in file: 2159.txt
# Class IDs changed to 0 in file: 2160.txt
# Class IDs changed to 0 in file: 2161.txt
# Class IDs changed to 0 in file: 2162.txt
# Class IDs changed to 0 in file: 2163.txt
# Class IDs changed to 0 in file: 2164.txt
# Class IDs changed to 0 in file: 2165.txt
# Class IDs changed to 0 in file: 2169.txt
# Class IDs changed to 0 in file: 2170.txt
# Class IDs changed to 0 in file: 2171.txt
# Class IDs changed to 0 in file: 2172.txt
# Class IDs changed to 0 in file: 2173.txt
# Class IDs changed to 0 in file: 2174.txt
# Class IDs changed to 0 in file: 2175.txt
# Class IDs changed to 0 in file: 2176.txt
# Class IDs changed to 0 in file: 2177.txt
# Class IDs changed to 0 in file: 2178.txt
# Class IDs changed to 0 in file: 2179.txt
# Class IDs changed to 0 in file: 2180.txt
# Class IDs changed to 0 in file: 2181.txt
# Class IDs changed to 0 in file: 2182.txt
# Class IDs changed to 0 in file: 2183.txt
# Class IDs changed to 0 in file: 2184.txt
# Class IDs changed to 0 in file: 2185.txt
# Class IDs changed to 0 in file: 2186.txt
# Class IDs changed to 0 in file: 2190.txt
# Class IDs changed to 0 in file: 2191.txt
# Class IDs changed to 0 in file: 2192.txt
# Class IDs changed to 0 in file: 2193.txt
# Class IDs changed to 0 in file: 2194.txt
# Class IDs changed to 0 in file: 2195.txt
# Class IDs changed to 0 in file: 2196.txt
# Class IDs changed to 0 in file: 2197.txt
# Class IDs changed to 0 in file: 2198.txt
# Class IDs changed to 0 in file: 2199.txt
# Class IDs changed to 0 in file: 2200.txt
# Class IDs changed to 0 in file: 2201.txt
# Class IDs changed to 0 in file: 2202.txt
# Class IDs changed to 0 in file: 2203.txt
# Class IDs changed to 0 in file: 2204.txt
# Class IDs changed to 0 in file: 2205.txt
# Class IDs changed to 0 in file: 2206.txt
# Class IDs changed to 0 in file: 2207.txt
# Class IDs changed to 0 in file: 2208.txt
# Class IDs changed to 0 in file: 2209.txt
# Class IDs changed to 0 in file: 2210.txt
# Class IDs changed to 0 in file: 2211.txt
# Class IDs changed to 0 in file: 2212.txt
# Class IDs changed to 0 in file: 2216.txt
# Class IDs changed to 0 in file: 2217.txt
# Class IDs changed to 0 in file: 2218.txt
# Class IDs changed to 0 in file: 2219.txt
# Class IDs changed to 0 in file: 2220.txt
# Class IDs changed to 0 in file: 2221.txt
# Class IDs changed to 0 in file: 2222.txt
# Class IDs changed to 0 in file: 2223.txt
# Class IDs changed to 0 in file: 2224.txt
# Class IDs changed to 0 in file: 2225.txt
# Class IDs changed to 0 in file: 2226.txt
# Class IDs changed to 0 in file: 2227.txt
# Class IDs changed to 0 in file: 2228.txt
# Class IDs changed to 0 in file: 2229.txt
# Class IDs changed to 0 in file: 2230.txt
# Class IDs changed to 0 in file: 2231.txt
# Class IDs changed to 0 in file: 2232.txt
# Class IDs changed to 0 in file: 2233.txt
# Class IDs changed to 0 in file: 2234.txt
# Class IDs changed to 0 in file: 2235.txt
# Class IDs changed to 0 in file: 2236.txt
# Class IDs changed to 0 in file: 2237.txt
# Class IDs changed to 0 in file: 2238.txt
# Class IDs changed to 0 in file: 2239.txt
# Class IDs changed to 0 in file: 2240.txt
# Class IDs changed to 0 in file: 2241.txt
# Class IDs changed to 0 in file: 2242.txt
# Class IDs changed to 0 in file: 2243.txt
# Class IDs changed to 0 in file: 2244.txt
# Class IDs changed to 0 in file: 2245.txt
# Class IDs changed to 0 in file: 2246.txt
# Class IDs changed to 0 in file: 2247.txt
# Class IDs changed to 0 in file: 2248.txt
# Class IDs changed to 0 in file: 2249.txt
# Class IDs changed to 0 in file: 2253.txt
# Class IDs changed to 0 in file: 2254.txt
# Class IDs changed to 0 in file: 2255.txt
# Class IDs changed to 0 in file: 2256.txt
# Class IDs changed to 0 in file: 2257.txt
# Class IDs changed to 0 in file: 2258.txt
# Class IDs changed to 0 in file: 2259.txt
# Class IDs changed to 0 in file: 2260.txt
# Class IDs changed to 0 in file: 2261.txt
# Class IDs changed to 0 in file: 2262.txt
# Class IDs changed to 0 in file: 2263.txt
# Class IDs changed to 0 in file: 2264.txt
# Class IDs changed to 0 in file: 2268.txt
# Class IDs changed to 0 in file: 2269.txt
# Class IDs changed to 0 in file: 2270.txt
# Class IDs changed to 0 in file: 2271.txt
# Class IDs changed to 0 in file: 2272.txt
# Class IDs changed to 0 in file: 2273.txt
# Class IDs changed to 0 in file: 2274.txt
# Class IDs changed to 0 in file: 2275.txt
# Class IDs changed to 0 in file: 2276.txt
# Class IDs changed to 0 in file: 2277.txt
# Class IDs changed to 0 in file: 2278.txt
# Class IDs changed to 0 in file: 2279.txt
# Class IDs changed to 0 in file: 2280.txt
# Class IDs changed to 0 in file: 2281.txt
# Class IDs changed to 0 in file: 2282.txt
# Class IDs changed to 0 in file: 2283.txt
# Class IDs changed to 0 in file: 2284.txt
# Class IDs changed to 0 in file: 2285.txt
# Class IDs changed to 0 in file: 2286.txt
# Class IDs changed to 0 in file: 2315.txt
# Class IDs changed to 0 in file: 2316.txt
# Class IDs changed to 0 in file: 2317.txt
# Class IDs changed to 0 in file: 2318.txt
# Class IDs changed to 0 in file: 2319.txt
# Class IDs changed to 0 in file: 2320.txt
# Class IDs changed to 0 in file: 2321.txt
# Class IDs changed to 0 in file: 2322.txt
# Class IDs changed to 0 in file: 2323.txt
# Class IDs changed to 0 in file: 2324.txt
# Class IDs changed to 0 in file: 2325.txt
# Class IDs changed to 0 in file: 2326.txt
# Class IDs changed to 0 in file: 2327.txt
# Class IDs changed to 0 in file: 2328.txt
# Class IDs changed to 0 in file: 2329.txt
# Class IDs changed to 0 in file: 2330.txt
# Class IDs changed to 0 in file: 2331.txt
# Class IDs changed to 0 in file: 2332.txt
# Class IDs changed to 0 in file: 2333.txt
# Class IDs changed to 0 in file: 2334.txt
# Class IDs changed to 0 in file: 2335.txt
# Class IDs changed to 0 in file: 2336.txt
# Class IDs changed to 0 in file: 2337.txt
# Class IDs changed to 0 in file: 2338.txt
# Class IDs changed to 0 in file: 2339.txt
# Class IDs changed to 0 in file: 2340.txt
# Class IDs changed to 0 in file: 2341.txt
# Class IDs changed to 0 in file: 2342.txt
# Class IDs changed to 0 in file: 2343.txt
# Class IDs changed to 0 in file: 2344.txt
# Class IDs changed to 0 in file: 2345.txt
# Class IDs changed to 0 in file: 2346.txt
# Class IDs changed to 0 in file: 2347.txt
# Class IDs changed to 0 in file: 2348.txt
# Class IDs changed to 0 in file: 2349.txt
# Class IDs changed to 0 in file: 2350.txt
# Class IDs changed to 0 in file: 2351.txt
# Class IDs changed to 0 in file: 2352.txt
# Class IDs changed to 0 in file: 2353.txt
# Class IDs changed to 0 in file: 2354.txt
# Class IDs changed to 0 in file: 2355.txt
# Class IDs changed to 0 in file: 2356.txt
# Class IDs changed to 0 in file: 2357.txt
# Class IDs changed to 0 in file: 2358.txt
# Class IDs changed to 0 in file: 2359.txt
# Class IDs changed to 0 in file: 2360.txt
# Class IDs changed to 0 in file: 2361.txt
# Class IDs changed to 0 in file: 2362.txt
# Class IDs changed to 0 in file: 2363.txt
# Class IDs changed to 0 in file: 2364.txt
# Class IDs changed to 0 in file: 2365.txt
# Class IDs changed to 0 in file: 2366.txt
# Class IDs changed to 0 in file: 2367.txt
# Class IDs changed to 0 in file: 2368.txt
# Class IDs changed to 0 in file: 2369.txt
# Class IDs changed to 0 in file: 2370.txt
# Class IDs changed to 0 in file: 2371.txt
# Class IDs changed to 0 in file: 2372.txt
# Class IDs changed to 0 in file: 2373.txt
# Class IDs changed to 0 in file: 2374.txt
# Class IDs changed to 0 in file: 2375.txt
# Class IDs changed to 0 in file: 2376.txt
# Class IDs changed to 0 in file: 2377.txt
# Class IDs changed to 0 in file: 2378.txt
# Class IDs changed to 0 in file: 2379.txt
# Class IDs changed to 0 in file: 2380.txt
# Class IDs changed to 0 in file: 2381.txt
# Class IDs changed to 0 in file: 2382.txt
# Class IDs changed to 0 in file: 2383.txt
# Class IDs changed to 0 in file: 2384.txt
# Class IDs changed to 0 in file: 2385.txt
# Class IDs changed to 0 in file: 2386.txt
# Class IDs changed to 0 in file: 2387.txt
# Class IDs changed to 0 in file: 2388.txt
# Class IDs changed to 0 in file: 2389.txt
# Class IDs changed to 0 in file: 2390.txt
# Class IDs changed to 0 in file: 2391.txt
# Class IDs changed to 0 in file: 2392.txt
# Class IDs changed to 0 in file: 2393.txt
# Class IDs changed to 0 in file: 2394.txt
# Class IDs changed to 0 in file: 2395.txt
# Class IDs changed to 0 in file: 2396.txt
# Class IDs changed to 0 in file: 2397.txt
# Class IDs changed to 0 in file: 2398.txt
# Class IDs changed to 0 in file: 2399.txt
# Class IDs changed to 0 in file: 2400.txt
# Class IDs changed to 0 in file: 2401.txt
# Class IDs changed to 0 in file: 2402.txt
# Class IDs changed to 0 in file: 2403.txt
# Class IDs changed to 0 in file: 2404.txt
# Class IDs changed to 0 in file: 2405.txt
# Class IDs changed to 0 in file: 2406.txt
# Class IDs changed to 0 in file: 2407.txt
# Class IDs changed to 0 in file: 2408.txt
# Class IDs changed to 0 in file: 2409.txt
# Class IDs changed to 0 in file: 2410.txt
# Class IDs changed to 0 in file: 2411.txt
# Class IDs changed to 0 in file: 2412.txt
# Class IDs changed to 0 in file: 2413.txt
# Class IDs changed to 0 in file: 2414.txt
# Class IDs changed to 0 in file: 2415.txt
# Class IDs changed to 0 in file: 2416.txt
# Class IDs changed to 0 in file: 2417.txt
# Class IDs changed to 0 in file: 2418.txt
# Class IDs changed to 0 in file: 2419.txt
# Class IDs changed to 0 in file: 2420.txt
# Class IDs changed to 0 in file: 2421.txt
# Class IDs changed to 0 in file: 2422.txt
# Class IDs changed to 0 in file: 2423.txt
# Class IDs changed to 0 in file: 2424.txt
# Class IDs changed to 0 in file: 2425.txt
# Class IDs changed to 0 in file: 2426.txt
# Class IDs changed to 0 in file: 2427.txt
# Class IDs changed to 0 in file: 2428.txt
# Class IDs changed to 0 in file: 2429.txt
# Class IDs changed to 0 in file: 2430.txt
# Class IDs changed to 0 in file: 2431.txt
# Class IDs changed to 0 in file: 2432.txt
# Class IDs changed to 0 in file: 2433.txt
# Class IDs changed to 0 in file: 2434.txt
# Class IDs changed to 0 in file: 2435.txt
# Class IDs changed to 0 in file: 2436.txt
# Class IDs changed to 0 in file: 2437.txt
# Class IDs changed to 0 in file: 2438.txt
# Class IDs changed to 0 in file: 2439.txt
# Class IDs changed to 0 in file: 2440.txt
# Class IDs changed to 0 in file: 2441.txt
# Class IDs changed to 0 in file: 2442.txt
# Class IDs changed to 0 in file: 2443.txt
# Class IDs changed to 0 in file: 2444.txt
# Class IDs changed to 0 in file: 2445.txt
# Class IDs changed to 0 in file: 2446.txt
# Class IDs changed to 0 in file: 2447.txt
# Class IDs changed to 0 in file: 2448.txt
# Class IDs changed to 0 in file: 2449.txt
# Class IDs changed to 0 in file: 2450.txt
# Class IDs changed to 0 in file: 2451.txt
# Class IDs changed to 0 in file: 2452.txt
# Class IDs changed to 0 in file: 2453.txt
# Class IDs changed to 0 in file: 2454.txt
# Class IDs changed to 0 in file: 2455.txt
# Class IDs changed to 0 in file: 2456.txt
# Class IDs changed to 0 in file: 2457.txt
# Class IDs changed to 0 in file: 2458.txt
# Class IDs changed to 0 in file: 2459.txt
# Class IDs changed to 0 in file: 2460.txt
# Class IDs changed to 0 in file: 2461.txt
# Class IDs changed to 0 in file: 2462.txt
# Class IDs changed to 0 in file: 2463.txt
# Class IDs changed to 0 in file: 2464.txt
# Class IDs changed to 0 in file: 2465.txt
# Class IDs changed to 0 in file: 2466.txt
# Class IDs changed to 0 in file: 2467.txt
# Class IDs changed to 0 in file: 2468.txt
# Class IDs changed to 0 in file: 2469.txt
# Class IDs changed to 0 in file: 2470.txt
# Class IDs changed to 0 in file: 2471.txt
# Class IDs changed to 0 in file: 2472.txt
# Class IDs changed to 0 in file: 2473.txt
# Class IDs changed to 0 in file: 2474.txt
# Class IDs changed to 0 in file: 2475.txt
# Class IDs changed to 0 in file: 2476.txt
# Class IDs changed to 0 in file: 2477.txt
# Class IDs changed to 0 in file: 2478.txt
# Class IDs changed to 0 in file: 2479.txt
# Class IDs changed to 0 in file: 2480.txt
# Class IDs changed to 0 in file: 2481.txt
# Class IDs changed to 0 in file: 2482.txt
# Class IDs changed to 0 in file: 2483.txt
# Class IDs changed to 0 in file: 2484.txt
# Class IDs changed to 0 in file: 2485.txt
# Class IDs changed to 0 in file: 2486.txt
# Class IDs changed to 0 in file: 2487.txt
# Class IDs changed to 0 in file: 2488.txt
# Class IDs changed to 0 in file: 2489.txt
# Class IDs changed to 0 in file: 2490.txt
# Class IDs changed to 0 in file: 2491.txt
# Class IDs changed to 0 in file: 2492.txt
# Class IDs changed to 0 in file: 2493.txt
# Class IDs changed to 0 in file: 2494.txt
# Class IDs changed to 0 in file: 2495.txt
# Class IDs changed to 0 in file: 2496.txt
# Class IDs changed to 0 in file: 2497.txt
# Class IDs changed to 0 in file: 2498.txt
# Class IDs changed to 0 in file: 2499.txt
# Class IDs changed to 0 in file: 2500.txt
